# %%
import pandas as pd
from pandas import Series, DataFrame

address = 'C:/Users/Ansela/Desktop/DataSet/mtcars.csv'
cars = pd.read_csv(address)

cars.columns = ['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

cars.index = cars.car_names
cars.head(10)
# Out:
#                            car_names   mpg  cyl   disp   hp  drat     wt  \
# car_names
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# Valiant                      Valiant  18.1    6  225.0  105  2.76  3.460
# Duster 360                Duster 360  14.3    8  360.0  245  3.21  3.570
# Merc 240D                  Merc 240D  24.4    4  146.7   62  3.69  3.190
# Merc 230                    Merc 230  22.8    4  140.8   95  3.92  3.150
# Merc 280                    Merc 280  19.2    6  167.6  123  3.92  3.440
#
#                     qsec  vs  am  gear  carb
# car_names
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# ...

# %%
#Plotting linechart using Object Oriented method

mpg =cars.mpg

fig = plt.figure() #1. generate blank figure, since obj oriented
ax = fig.add_axes([.1,.1,1,1]) #2. add axes to figure
mpg.plot()

ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation = 80,fontsize='medium')
ax.set_title('Miles per gallon of cars in mtcars dataset', color ='green')
ax.set_xlabel('Car names', color ='green')
ax.set_ylabel('Miles per gallon', color ='green')
ax.legend(loc='best')
ax.set_ylim([0,45])
# Out:
# (0.0, 45.0)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

df = cars[['cyl','wt','mpg']]
df.plot()
# Out:
# <AxesSubplot:xlabel='car_names'>

# %%
mpg.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='car_names'>

# %%
import seaborn as sb
sb.set_style('whitegrid')

sb.regplot(x= 'hp', y='mpg',data=cars, scatter= True)
# Out:
# <AxesSubplot:xlabel='hp', ylabel='mpg'>

# %%
cars_subset = cars[['mpg','disp','hp','wt']]
sb.pairplot(cars_subset)
plt.show()

# %%
#to find out row index with max value
mpg = cars.mpg
mpg
# Out:
# car_names
# Mazda RX4              21.0
# Mazda RX4 Wag          21.0
# Datsun 710             22.8
# Hornet 4 Drive         21.4
# Hornet Sportabout      18.7
# Valiant                18.1
# Duster 360             14.3
# Merc 240D              24.4
# Merc 230               22.8
# Merc 280               19.2
# Merc 280C              17.8
# Merc 450SE             16.4
# Merc 450SL             17.3
# Merc 450SLC            15.2
# Cadillac Fleetwood     10.4
# Lincoln Continental    10.4
# Chrysler Imperial      14.7
# Fiat 128               32.4
# Honda Civic            30.4
# Toyota Corolla         33.9
# Toyota Corona          21.5
# Dodge Challenger       15.5
# AMC Javelin            15.2
# Camaro Z28             13.3
# Pontiac Firebird       19.2
# Fiat X1-9              27.3
# Porsche 914-2          26.0
# Lotus Europa           30.4
# Ford Pantera L         15.8
# Ferrari Dino           19.7
# Maserati Bora          15.0
# Volvo 142E             21.4
# Name: mpg, dtype: float64

# %%
mpg.idxmax()
# Out:
# 'Toyota Corolla'

# %%
cars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...
